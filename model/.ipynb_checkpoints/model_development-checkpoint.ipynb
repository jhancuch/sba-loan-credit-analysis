# %% [markdown]
# Base models without a grid search will first be fitted to get a sense of which work best with the imbalanced dataset. Each model will be fitted with various iterations of the dataset. Then, models are down selected and greater tuning through grid searches occur before finally settling on a final model.

# %%
import pandas as pd
import numpy as np
import pickle 
import os 

# %matplotlib inline

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.pipeline import make_pipeline, Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.linear_model import Lasso
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score, roc_curve, RocCurveDisplay, auc, PrecisionRecallDisplay

# %%
pd.set_option('display.max_rows', 100)

# %% [markdown]
# # Data Prep

# %% [markdown]
# ## Load data

# %%
data1 = pd.read_csv('https://data.sba.gov/dataset/0ff8e8e9-b967-4f4e-987c-6ac78c575087/resource/c71ba6cf-b4e0-4e60-98f0-48aeaf4c6460/download/foia-7afy2020-present-asof-220331.csv', 
                    encoding = "ISO-8859-1", low_memory = False)

data2 = pd.read_csv('https://data.sba.gov/dataset/0ff8e8e9-b967-4f4e-987c-6ac78c575087/resource/02e2e83a-2af1-4ce8-91db-85e20ffadbf7/download/foia-7afy2010-fy2019-asof-220331.csv', 
                    encoding = "ISO-8859-1", low_memory = False)

data3 = pd.read_csv('https://data.sba.gov/dataset/0ff8e8e9-b967-4f4e-987c-6ac78c575087/resource/95d6972c-38df-4ecf-8f0a-eed224e8b02c/download/foia-7afy2000-fy2009-asof-220331.csv', 
                    encoding = "ISO-8859-1", low_memory = False)

data = pd.concat([data1, data2, data3], ignore_index=True).reset_index(drop=True)

# %%
# subset to observations with the LoanStatus PIF or CHGOFF aka paid in full or charged off. We don't care about loans that are currently being paid back
df = data[(data['LoanStatus'] == 'PIF') | (data['LoanStatus'] == 'CHGOFF')].drop_duplicates().reset_index(drop=True)

# convert PIF to 0 and CHGOFF to 1
df.loc[df['LoanStatus'] == 'PIF', 'LoanStatus'] = '0' 
df.loc[df['LoanStatus'] == 'CHGOFF', 'LoanStatus'] = '1'
df['LoanStatus'] = df['LoanStatus'].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 931860 entries, 0 to 931859
# Data columns (total 39 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   AsOfDate               931860 non-null  int64
#  1   Program                931860 non-null  object
#  2   BorrName               931844 non-null  object
#  3   BorrStreet             931840 non-null  object
#  4   BorrCity               931850 non-null  object
#  5   BorrState              931850 non-null  object
#  6   BorrZip                931860 non-null  int64
#  7   BankName               931860 non-null  object
#  8   BankFDICNumber         851310 non-null  float64
#  9   BankNCUANumber         20674 non-null   float64
#  10  BankStreet             931824 non-null  object
#  11  BankCity               931824 non-null  object
#  12  BankState              931818 non-null  object
#  13  BankZip                931824 non-null  object
#  14  GrossApproval          931850 non-null  float64
#  15  SBAGuaranteedApproval  931850 non-null  float64
#  16  ApprovalDate           931860 non-null  object
#  17  ApprovalFiscalYear     931860 non-null  int64
#  18  FirstDisbursementDate  929283 non-null  object
#  19  DeliveryMethod         931850 non-null  object
#  20  subpgmdesc             931860 non-null  object
#  21  InitialInterestRate    364238 non-null  float64
#  22  TermInMonths           931860 non-null  int64
#  23  NaicsCode              915033 non-null  float64
#  24  NaicsDescription       914811 non-null  object
#  25  FranchiseCode          59504 non-null   object
#  26  FranchiseName          59463 non-null   object
#  27  ProjectCounty          931700 non-null  object
#  28  ProjectState           931850 non-null  object
#  29  SBADistrictOffice      931850 non-null  object
#  30  CongressionalDistrict  929710 non-null  float64
#  31  BusinessType           931818 non-null  object
#  32  BusinessAge            36896 non-null   object
#  33  LoanStatus             931860 non-null  int64
#  34  PaidInFullDate         758354 non-null  object
#  35  ChargeOffDate          173501 non-null  object
#  36  GrossChargeOffAmount   931860 non-null  int64
#  37  RevolverStatus         931860 non-null  int64
#  38  JobsSupported          931860 non-null  int64
# dtypes: float64(7), int64(8), object(24)
# memory usage: 277.3+ MB

# %% [markdown]
# ## Create core dataset (interest rate included)

# %%
core = df[['LoanStatus', 'BankName', 'RevolverStatus', 'TermInMonths', 'InitialInterestRate', 'ApprovalFiscalYear', 'NaicsCode', 'subpgmdesc', 'BankState', 'BorrState']].copy().dropna()

# Same state for Bank and Borrower
core['BorrBankSameState'] = 0
core.loc[core.BankState == core.BorrState, 'BorrBankSameState'] = 1

# Number of total loans, total defaults, and percentage of default for each bank
df_BankDefaults = pd.merge(pd.DataFrame(df.groupby('BankName')['LoanStatus'].count()).reset_index().rename(columns={'LoanStatus':'TotLoanCounts'}), 
                           pd.DataFrame(df.groupby('BankName')['LoanStatus'].sum()).reset_index().rename(columns={'LoanStatus':'TotDefaultCounts'}), 
                           how='inner', on='BankName')
core = pd.merge(core[['LoanStatus', 'BankName', 'RevolverStatus', 'TermInMonths', 'InitialInterestRate', 'BorrBankSameState', 'ApprovalFiscalYear', 'NaicsCode', 'subpgmdesc']], 
                df_BankDefaults, 
                how='inner', 
                on='BankName')
core['TotPctDefault'] = core['TotDefaultCounts']/core['TotLoanCounts']

# Number of yearly loans, yearly defaults, and percentage of default for each bank for each year of issuance 
df_BankDefaultsYearly = pd.merge(pd.DataFrame(df.groupby(['BankName', 'ApprovalFiscalYear'])['LoanStatus'].count()).reset_index().rename(columns={'LoanStatus':'YearlyLoanCounts'}), 
                           pd.DataFrame(df.groupby(['BankName', 'ApprovalFiscalYear'])['LoanStatus'].sum()).reset_index().rename(columns={'LoanStatus':'YearlyDefaultCounts'}), 
                           how='inner', on=['BankName', 'ApprovalFiscalYear'])
core = pd.merge(core[['LoanStatus', 'BankName', 'ApprovalFiscalYear', 'RevolverStatus', 'TermInMonths', 'InitialInterestRate', 'BorrBankSameState',
                     'TotPctDefault', 'TotDefaultCounts', 'TotLoanCounts', 'NaicsCode', 'subpgmdesc']], 
                df_BankDefaultsYearly, 
                how='inner', 
                on=['BankName', 'ApprovalFiscalYear'])
core['YearlyPctDefault'] = core['YearlyDefaultCounts']/core['YearlyLoanCounts']

# %% [markdown]
# ## Create features to test

# %%
# Just the community express dummy indicator
core_small = core.copy()
core_small['subpgmdesc_community_express'] = 0
core_small.loc[core_small.subpgmdesc == 'Community Express', 'subpgmdesc_community_express'] = 1

# Dummy variables for all of the sub program descriptions
core_large = pd.merge(core.drop('subpgmdesc', axis=1), pd.get_dummies(core['subpgmdesc'], prefix = 'subpgmdesc_', drop_first=True), how='inner', left_index = True, right_index = True)

# %%
# core_small gets none of the naics codes
core_small.drop('NaicsCode', axis=1, inplace=True)

# core_large gets all of the naics codes
core_large['NaicsCode'] = core_large['NaicsCode'].astype(str)
core_large['NaicsCode'] = core_large['NaicsCode'].str.slice(stop=2)
core_large['NaicsCode'] = core_large['NaicsCode'].astype(int)
core_large = pd.merge(core_large.drop('NaicsCode', axis=1), pd.get_dummies(core_large['NaicsCode'], prefix = 'NaicsCode_', drop_first=True), how='inner', left_index = True, right_index = True)

# %%
# core_small just has dummy variables for 2006 and 2007
core_small['Year2006'] = 0
core_small.loc[core_small.ApprovalFiscalYear == 2006, 'Year2006'] = 1

core_small['Year2007'] = 0
core_small.loc[core_small.ApprovalFiscalYear == 2007, 'Year2007'] = 1

# %%
# core_large has dummy variables for all years
core_large = pd.merge(core_large.drop('ApprovalFiscalYear', axis=1), pd.get_dummies(core_large['ApprovalFiscalYear'], prefix = 'ApprovalFiscalYear_', drop_first=True), how='inner', left_index = True, right_index = True)

# %%
# remove unnecessary variables
core_small.drop(['BankName', 'ApprovalFiscalYear', 'subpgmdesc'], axis=1, inplace=True)
core_large.drop(['BankName'], axis=1, inplace=True)

# %%
plt.figure(figsize=(20,8))
sns.heatmap(core_small.corr(), vmin = -1, vmax = 1, annot=True, cmap = 'crest')
plt.show()

# %%
core_small.drop(['TotDefaultCounts', 'TotLoanCounts'], axis=1, inplace=True)

# %%
core_large.drop(['TotDefaultCounts', 'TotLoanCounts'], axis=1, inplace=True)

# %% [markdown]
# ## Create core dataset (without interest rate)

# %%
core_no_int = df[['LoanStatus', 'BankName', 'RevolverStatus', 'TermInMonths', 'ApprovalFiscalYear', 'NaicsCode', 'subpgmdesc', 'BankState', 'BorrState']].copy().dropna()

# Same state for Bank and Borrower
core_no_int['BorrBankSameState'] = 0
core_no_int.loc[core_no_int.BankState == core_no_int.BorrState, 'BorrBankSameState'] = 1

# Number of total loans, total defaults, and percentage of default for each bank
df_BankDefaults = pd.merge(pd.DataFrame(df.groupby('BankName')['LoanStatus'].count()).reset_index().rename(columns={'LoanStatus':'TotLoanCounts'}), 
                           pd.DataFrame(df.groupby('BankName')['LoanStatus'].sum()).reset_index().rename(columns={'LoanStatus':'TotDefaultCounts'}), 
                           how='inner', on='BankName')
core_no_int = pd.merge(core_no_int[['LoanStatus', 'BankName', 'RevolverStatus', 'TermInMonths', 'BorrBankSameState', 'ApprovalFiscalYear', 'NaicsCode', 'subpgmdesc']], 
                df_BankDefaults, 
                how='inner', 
                on='BankName')
core_no_int['TotPctDefault'] = core_no_int['TotDefaultCounts']/core_no_int['TotLoanCounts']

# Number of yearly loans, yearly defaults, and percentage of default for each bank for each year of issuance 
df_BankDefaultsYearly = pd.merge(pd.DataFrame(df.groupby(['BankName', 'ApprovalFiscalYear'])['LoanStatus'].count()).reset_index().rename(columns={'LoanStatus':'YearlyLoanCounts'}), 
                           pd.DataFrame(df.groupby(['BankName', 'ApprovalFiscalYear'])['LoanStatus'].sum()).reset_index().rename(columns={'LoanStatus':'YearlyDefaultCounts'}), 
                           how='inner', on=['BankName', 'ApprovalFiscalYear'])
core_no_int = pd.merge(core_no_int[['LoanStatus', 'BankName', 'ApprovalFiscalYear', 'RevolverStatus', 'TermInMonths', 'BorrBankSameState',
                     'TotPctDefault', 'TotDefaultCounts', 'TotLoanCounts', 'NaicsCode', 'subpgmdesc']], 
                df_BankDefaultsYearly, 
                how='inner', 
                on=['BankName', 'ApprovalFiscalYear'])
core_no_int['YearlyPctDefault'] = core_no_int['YearlyDefaultCounts']/core_no_int['YearlyLoanCounts']

# %% [markdown]
# ## Create features to test

# %%
# Just the community express dummy indicator
core_no_int_small = core_no_int.copy()
core_no_int_small['subpgmdesc_community_express'] = 0
core_no_int_small.loc[core_no_int_small.subpgmdesc == 'Community Express', 'subpgmdesc_community_express'] = 1

# Dummy variables for all of the sub program descriptions
core_no_int_large = pd.merge(core_no_int.drop('subpgmdesc', axis=1), pd.get_dummies(core_no_int['subpgmdesc'], prefix = 'subpgmdesc_', drop_first=True), how='inner', left_index = True, right_index = True)

# %%
# core_small gets none of the naics codes
core_no_int_small.drop('NaicsCode', axis=1, inplace=True)

# core_large gets all of the naics codes
core_no_int_large['NaicsCode'] = core_no_int_large['NaicsCode'].astype(str)
core_no_int_large['NaicsCode'] = core_no_int_large['NaicsCode'].str.slice(stop=2)
core_no_int_large['NaicsCode'] = core_no_int_large['NaicsCode'].astype(int)
core_no_int_large = pd.merge(core_no_int_large.drop('NaicsCode', axis=1), pd.get_dummies(core_no_int_large['NaicsCode'], prefix = 'NaicsCode_', drop_first=True), how='inner', left_index = True, right_index = True)

# %%
# core_small just has dummy variables for 2006 and 2007
core_no_int_small['Year2006'] = 0
core_no_int_small.loc[core_no_int_small.ApprovalFiscalYear == 2006, 'Year2006'] = 1

core_no_int_small['Year2007'] = 0
core_no_int_small.loc[core_no_int_small.ApprovalFiscalYear == 2007, 'Year2007'] = 1

# %%
# core_large has dummy variables for all years
core_no_int_large = pd.merge(core_no_int_large.drop('ApprovalFiscalYear', axis=1), pd.get_dummies(core_no_int_large['ApprovalFiscalYear'], prefix = 'ApprovalFiscalYear_', drop_first=True), how='inner', left_index = True, right_index = True)

# %%
# remove unnecessary variables
core_no_int_small.drop(['BankName', 'ApprovalFiscalYear', 'subpgmdesc'], axis=1, inplace=True)
core_no_int_large.drop(['BankName'], axis=1, inplace=True)

# %%
plt.figure(figsize=(20,8))
sns.heatmap(core_no_int_small.corr(), vmin = -1, vmax = 1, annot=True, cmap = 'crest')
plt.show()

# %%
core_no_int_small.drop(['TotDefaultCounts', 'TotLoanCounts'], axis=1, inplace=True)
core_no_int_large.drop(['TotDefaultCounts', 'TotLoanCounts'], axis=1, inplace=True)

# %%
plt.figure(figsize=(20,8))
sns.heatmap(core_no_int_small.corr(), vmin = -1, vmax = 1, annot=True, cmap = 'crest')
plt.show()

# %%
core_no_int_small.drop(['YearlyLoanCounts'], axis=1, inplace=True)
core_no_int_large.drop(['YearlyLoanCounts'], axis=1, inplace=True)

# %% [markdown]
# # Models

# %%
def compute_eval(actual, pred):
    fpr, tpr, thresholds = roc_curve(actual, pred)
    roc_auc = auc(fpr, tpr)
    display = RocCurveDisplay(fpr=fpr, tpr=tpr, roc_auc=roc_auc)
    display.plot()
    plt.show()

# %% [markdown]
# ## Split

# %%
X_train_core_small, X_validation_core_small, y_train_core_small, y_validation_core_small = train_test_split(core_small.iloc[:, 1:], core_small.iloc[:, 0], test_size=0.2, random_state=123)
X_train_core_large, X_validation_core_large, y_train_core_large, y_validation_core_large = train_test_split(core_large.iloc[:, 1:], core_large.iloc[:, 0], test_size=0.2, random_state=123)
X_train_core_no_int_small, X_validation_core_no_int_small, y_train_core_no_int_small, y_validation_core_no_int_small = train_test_split(core_no_int_small.iloc[:, 1:], core_no_int_small.iloc[:, 0], test_size=0.2, random_state=123)
X_train_core_no_int_large, X_validation_core_no_int_large, y_train_core_no_int_large, y_validation_core_no_int_large = train_test_split(core_no_int_large.iloc[:, 1:], core_no_int_large.iloc[:, 0], test_size=0.2, random_state=123)

# %% [markdown]
# ## Random Forest

# %%
rf_pipe = Pipeline([("scaler", StandardScaler()), ("model", RandomForestClassifier())])

# %% [markdown]
# ### core_small

# %%
rf = Pipeline([("scaler", StandardScaler()), ("model", RandomForestClassifier(class_weight='balanced'))])
rf.fit(X_train_core_small, y_train_core_small.ravel())
rf_predictions = rf.predict(X_validation_core_small)

# %%
print(classification_report(y_validation_core_small, rf_predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.98     63617
#            1       0.81      0.71      0.76      6257
#
#     accuracy                           0.96     69874
#    macro avg       0.89      0.85      0.87     69874
# weighted avg       0.96      0.96      0.96     69874

# %%
compute_auc(y_validation_core_small, rf_predictions)

# %% [markdown]
# ### core_large

# %%
rf = Pipeline([("scaler", StandardScaler()), ("model", RandomForestClassifier(class_weight='balanced'))])
rf.fit(X_train_core_large, y_train_core_large.ravel())
rf_predictions = rf.predict(X_validation_core_large)

# %%
print(classification_report(y_validation_core_large, rf_predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98     63617
#            1       0.85      0.64      0.73      6257
#
#     accuracy                           0.96     69874
#    macro avg       0.91      0.81      0.85     69874
# weighted avg       0.95      0.96      0.95     69874

# %%
compute_auc(y_validation_core_large, rf_predictions)

# %% [markdown]
# ### core_no_int_small

# %%
rf = Pipeline([("scaler", StandardScaler()), ("model", RandomForestClassifier(class_weight='balanced'))])
rf.fit(X_train_core_no_int_small, y_train_core_no_int_small.ravel())
rf_predictions = rf.predict(X_validation_core_no_int_small)

# %%
print(classification_report(y_validation_core_no_int_small, rf_predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.95      0.96    145797
#            1       0.80      0.84      0.82     34117
#
#     accuracy                           0.93    179914
#    macro avg       0.88      0.89      0.89    179914
# weighted avg       0.93      0.93      0.93    179914

# %%
compute_auc(y_validation_core_no_int_small, rf_predictions)

# %% [markdown]
# ### core_no_int_large

# %%
rf = Pipeline([("scaler", StandardScaler()), ("model", RandomForestClassifier(class_weight='balanced'))])
rf.fit(X_train_core_no_int_large, y_train_core_no_int_large.ravel())
rf_predictions = rf.predict(X_validation_core_no_int_large)

# %%
print(classification_report(y_validation_core_no_int_large, rf_predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.96      0.95    145797
#            1       0.82      0.76      0.79     34117
#
#     accuracy                           0.92    179914
#    macro avg       0.88      0.86      0.87    179914
# weighted avg       0.92      0.92      0.92    179914

# %%
compute_auc(y_validation_core_no_int_large, rf_predictions)

# %% [markdown]
# ## XGBOOST

# %% [markdown]
# ### core_small

# %%
xgb = Pipeline([("scaler", StandardScaler()), ("model", XGBClassifier(use_label_encoder=False))])
xgb.fit(X_train_core_small, y_train_core_small.ravel())
xgb_predictions = xgb.predict(X_validation_core_small)
# Out:
# [20:10:51] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1643226942235/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.

# %%
print(classification_report(y_validation_core_small, xgb_predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98     63617
#            1       0.82      0.79      0.81      6257
#
#     accuracy                           0.97     69874
#    macro avg       0.90      0.89      0.89     69874
# weighted avg       0.97      0.97      0.97     69874

# %%
compute_auc(y_validation_core_small, xgb_predictions)

# %% [markdown]
# ### core_large

# %%
xgb = Pipeline([("scaler", StandardScaler()), ("model", XGBClassifier(use_label_encoder=False))])
xgb.fit(X_train_core_large, y_train_core_large.ravel())
xgb_predictions = xgb.predict(X_validation_core_large)
# Out:
# [20:11:51] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1643226942235/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.

# %%
print(classification_report(y_validation_core_large, xgb_predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.98      0.98     63617
#            1       0.83      0.80      0.82      6257
#
#     accuracy                           0.97     69874
#    macro avg       0.91      0.89      0.90     69874
# weighted avg       0.97      0.97      0.97     69874

# %%
compute_auc(y_validation_core_large, xgb_predictions)

# %% [markdown]
# ### core_no_int_small

# %%
xgb = Pipeline([("scaler", StandardScaler()), ("model", XGBClassifier(use_label_encoder=False))])
xgb.fit(X_train_core_no_int_small, y_train_core_no_int_small.ravel())
xgb_predictions = xgb.predict(X_validation_core_no_int_small)
# Out:
# [20:13:26] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1643226942235/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.

# %%
print(classification_report(y_validation_core_no_int_small, xgb_predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.96      0.96    145797
#            1       0.82      0.85      0.84     34117
#
#     accuracy                           0.94    179914
#    macro avg       0.89      0.91      0.90    179914
# weighted avg       0.94      0.94      0.94    179914

# %%
compute_auc(y_validation_core_no_int_small, xgb_predictions)

# %% [markdown]
# ### core_no_int_large

# %%
xgb = Pipeline([("scaler", StandardScaler()), ("model", XGBClassifier(use_label_encoder=False))])
xgb.fit(X_train_core_no_int_large, y_train_core_no_int_large.ravel())
xgb_predictions = xgb.predict(X_validation_core_no_int_large)
# Out:
# [20:14:24] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1643226942235/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.

# %%
print(classification_report(y_validation_core_no_int_large, xgb_predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.96      0.96    145797
#            1       0.83      0.86      0.85     34117
#
#     accuracy                           0.94    179914
#    macro avg       0.90      0.91      0.90    179914
# weighted avg       0.94      0.94      0.94    179914

# %%
compute_auc(y_validation_core_no_int_large, xgb_predictions)

# %% [markdown]
# ## Refine Model
#
# XGBOOST classifier with both datasets that exclude the interest rate (but have double the observations) perform the best. I will be using grid search to determine the optimal hyper-parameters

# %%
xgb = Pipeline([("scaler", StandardScaler()), ("model", XGBClassifier(use_label_encoder=False, verbosity = 1))])

# %%
xgb_params = {'model__scale_pos_weight': [1, 2, 5],
              'model__grow_policy': ['depthwise', 'lossguide'],
              'model__n_estimators': [100, 300]
             }

# %% [markdown]
# ### XBOOST - core_no_int_small

# %%
xgb_no_int_small_search = GridSearchCV(estimator=xgb, param_grid=xgb_params, verbose = 1, scoring = 'roc_auc', n_jobs=3)
xgb_no_int_small_search.fit(X_train_core_no_int_small, y_train_core_no_int_small)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# [20:45:46] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1643226942235/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# GridSearchCV(estimator=Pipeline(steps=[('scaler', StandardScaler()),
#                                        ('model',
#                                         XGBClassifier(base_score=None,
#                                                       booster=None,
#                                                       colsample_bylevel=None,
#                                                       colsample_bynode=None,
#                                                       colsample_bytree=None,
#                                                       enable_categorical=False,
#                                                       gamma=None, gpu_id=None,
#                                                       importance_type=None,
#                                                       interaction_constraints=None,
#                                                       learning_rate=None,
#                                                       max_delta_step=None,
#                                                       max_depth=None,
#                                                       min_child_we...
#                                                       num_parallel_tree=None,
#                                                       predictor=None,
#                                                       random_state=None,
#                                                       reg_alpha=None,
#                                                       reg_lambda=None,
#                                                       scale_pos_weight=None,
#                                                       subsample=None,
#                                                       tree_method=None,
#                                                       use_label_encoder=False,
#                                                       validate_parameters=None,
#                                                       verbosity=1))]),
#              n_jobs=3,
#              param_grid={'model__grow_policy': ['depthwise', 'lossguide'],
#                          'model__n_estimators': [100, 300],
#                          'model__scale_pos_weight': [1, 2, 5]},
#              scoring='roc_auc', verbose=1)

# %%
print("Best parameter (CV score=%0.3f):" % xgb_no_int_small_search.best_score_)
print(xgb_no_int_small_search.best_params_)
# Out:
# Best parameter (CV score=0.975):
# {'model__grow_policy': 'depthwise', 'model__n_estimators': 300, 'model__scale_pos_weight': 1}
# [20:14:36] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1643226942235/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [20:15:24] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1643226942235/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [20:16:10] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1643226942235/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [20:16:55] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1643226942235/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [20:17:40] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1643226942235/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [20:18:26] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1643226942235/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [20:20:45] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1643226942235/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [20:23:00] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1643226942235/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [20:25:17] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1643226942235/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [20:27:37] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1643226942235/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [20:30:02] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1643226942235/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [20:30:48] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1643226942235/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [20:31:34] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1643226942235/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [20:32:22] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1643226942235/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [20:33:09] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1643226942235/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [20:33:54] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1643226942235/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [20:36:13] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1643226942235/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [20:38:33] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1643226942235/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [20:40:48] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1643226942235/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [20:43:08] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1643226942235/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [20:14:36] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1643226942235/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [20:15:24] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1643226942235/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [20:16:09] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1643226942235/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [20:16:55] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1643226942235/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [20:17:40] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1643226942235/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [20:18:26] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1643226942235/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [20:20:46] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1643226942235/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [20:23:01] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1643226942235/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [20:25:17] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1643226942235/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [20:27:36] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1643226942235/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [20:30:01] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1643226942235/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [20:30:48] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1643226942235/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [20:31:36] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1643226942235/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [20:32:23] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1643226942235/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [20:33:10] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1643226942235/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [20:33:56] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1643226942235/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [20:36:15] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1643226942235/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [20:38:35] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1643226942235/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [20:40:51] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1643226942235/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [20:43:11] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1643226942235/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [20:14:36] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1643226942235/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [20:15:24] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1643226942235/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [20:16:10] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1643226942235/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [20:16:54] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1643226942235/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [20:17:40] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1643226942235/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [20:18:25] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1643226942235/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [20:20:44] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1643226942235/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [20:23:02] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1643226942235/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [20:25:20] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1643226942235/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [20:27:41] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1643226942235/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [20:30:06] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1643226942235/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [20:30:53] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1643226942235/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [20:31:40] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1643226942235/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [20:32:27] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1643226942235/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [20:33:14] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1643226942235/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [20:33:59] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1643226942235/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [20:36:17] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1643226942235/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [20:38:38] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1643226942235/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [20:40:54] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1643226942235/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [20:43:15] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1643226942235/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.

# %% [markdown]
# ### XBOOST - core_no_int_large

# %%
xgb_no_int_large_search = GridSearchCV(estimator=xgb, param_grid=xgb_params, verbose = 1, scoring = 'roc_auc', n_jobs=3)
xgb_no_int_large_search.fit(X_train_core_no_int_large, y_train_core_no_int_large)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# /home/jhancuch/miniconda3/lib/python3.9/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# /home/jhancuch/miniconda3/lib/python3.9/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# /home/jhancuch/miniconda3/lib/python3.9/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# [11:36:14] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1643226942235/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# GridSearchCV(estimator=Pipeline(steps=[('scaler', StandardScaler()),
#                                        ('model',
#                                         XGBClassifier(base_score=None,
#                                                       booster=None,
#                                                       colsample_bylevel=None,
#                                                       colsample_bynode=None,
#                                                       colsample_bytree=None,
#                                                       enable_categorical=False,
#                                                       gamma=None, gpu_id=None,
#                                                       importance_type=None,
#                                                       interaction_constraints=None,
#                                                       learning_rate=None,
#                                                       max_delta_step=None,
#                                                       max_depth=None,
#                                                       min_child_we...
#                                                       num_parallel_tree=None,
#                                                       predictor=None,
#                                                       random_state=None,
#                                                       reg_alpha=None,
#                                                       reg_lambda=None,
#                                                       scale_pos_weight=None,
#                                                       subsample=None,
#                                                       tree_method=None,
#                                                       use_label_encoder=False,
#                                                       validate_parameters=None,
#                                                       verbosity=1))]),
#              n_jobs=3,
#              param_grid={'model__grow_policy': ['depthwise', 'lossguide'],
#                          'model__n_estimators': [100, 300],
#                          'model__scale_pos_weight': [1, 2, 5]},
#              scoring='roc_auc', verbose=1)

# %%
print("Best parameter (CV score=%0.3f):" % xgb_no_int_large_search.best_score_)
print(xgb_no_int_large_search.best_params_)
# Out:
# Best parameter (CV score=0.977):
# {'model__grow_policy': 'depthwise', 'model__n_estimators': 300, 'model__scale_pos_weight': 1}
# [09:57:42] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1643226942235/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [10:00:29] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1643226942235/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [10:03:14] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1643226942235/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [10:06:01] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1643226942235/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [10:08:54] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1643226942235/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [10:12:08] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1643226942235/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [10:20:42] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1643226942235/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [10:29:03] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1643226942235/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [10:37:25] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1643226942235/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [10:45:46] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1643226942235/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [10:52:09] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1643226942235/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [10:54:16] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1643226942235/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [10:56:25] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1643226942235/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [10:58:45] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1643226942235/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [11:00:51] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1643226942235/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [11:02:59] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1643226942235/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [11:09:14] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1643226942235/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [11:15:27] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1643226942235/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [11:21:57] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1643226942235/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [11:29:02] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1643226942235/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:57:42] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1643226942235/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [10:00:30] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1643226942235/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [10:03:14] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1643226942235/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [10:06:02] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1643226942235/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [10:08:54] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1643226942235/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [10:12:10] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1643226942235/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [10:20:47] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1643226942235/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [10:29:06] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1643226942235/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [10:37:26] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1643226942235/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [10:45:55] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1643226942235/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [10:52:17] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1643226942235/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [10:54:22] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1643226942235/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [10:56:31] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1643226942235/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [10:58:49] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1643226942235/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [11:00:56] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1643226942235/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [11:03:03] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1643226942235/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [11:09:17] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1643226942235/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [11:15:31] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1643226942235/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [11:22:02] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1643226942235/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [11:29:09] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1643226942235/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [09:57:43] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1643226942235/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [10:00:31] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1643226942235/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [10:03:17] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1643226942235/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [10:06:04] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1643226942235/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [10:08:58] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1643226942235/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [10:12:14] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1643226942235/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [10:20:48] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1643226942235/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [10:29:09] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1643226942235/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [10:37:35] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1643226942235/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [10:46:09] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1643226942235/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [10:52:26] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1643226942235/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [10:54:32] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1643226942235/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [10:56:45] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1643226942235/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [10:59:03] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1643226942235/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [11:01:11] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1643226942235/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [11:03:18] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1643226942235/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [11:09:32] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1643226942235/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [11:15:46] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1643226942235/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [11:22:20] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1643226942235/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [11:29:29] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1643226942235/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.

# %% [markdown]
# ## Export
# Export XGBoost model to be able to serve it on GCP application

# %%
xgb = XGBClassifier(use_label_encoder=False,
                    grow_policy = 'depthwise',
                    n_estimators = 300, 
                    scale_pos_weight = 1)
xgb.fit(X_train_core_no_int_large, y_train_core_no_int_large.ravel())
# Out:
# /home/jhancuch/miniconda3/lib/python3.9/site-packages/xgboost/data.py:262: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   elif isinstance(data.columns, (pd.Int64Index, pd.RangeIndex)):
# [15:53:23] WARNING: /home/conda/feedstock_root/build_artifacts/xgboost-split_1643226942235/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#               gamma=0, gpu_id=-1, grow_policy='depthwise', importance_type=None,
#               interaction_constraints='', learning_rate=0.300000012,
#               max_delta_step=0, max_depth=6, min_child_weight=1, missing=nan,
#               monotone_constraints='()', n_estimators=300, n_jobs=8,
#               num_parallel_tree=1, predictor='auto', random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#               tree_method='exact', use_label_encoder=False,
#               validate_parameters=1, verbosity=None)

# %%
artifact_filename = 'model.pkl'

# Save model artifact to local filesystem (doesn't persist)
local_path = artifact_filename
with open(local_path, 'wb') as model_file:
  pickle.dump(xgb, model_file)

# %%
xgb.save_model('model.bst')
